# %% [markdown]
# # Table of Contents
# 1 Importing Libraries
#
# 2 If Statements
#
# 3 If Statements with the loc() Function
#
# 4 If Statements with For-Loops
#
# 5 Task
#
# 02. Suppose your clients have changed their minds about the labels you created in your “busiest_day” column. Now, they want “Busiest day” to become “Busiest days” (plural). This label should correspond with the two busiest days of the week as opposed to the single busiest day. At the same time, they’d also like to know the two slowest days. Create a new column for this using a suitable method.
#
# 03. Check the values of this new column for accuracy. Note any observations in markdown format.
#
# 04. When too many users make Instacart orders at the same time, the app freezes. The senior technical officer at Instacart wants you to identify the busiest hours of the day. Rather than by hour, they want periods of time labeled “Most orders,” “Average orders,” and “Fewest orders.” Create a new column containing these labels called “busiest_period_of_day.”
#
# 05. Print the frequency for this new column.
#
# 07. Export your dataframe as a pickle file (since you added new columns) and store it correctly in your “Prepared Data” folder.

# %% [markdown]
# # 1 Importing Libraries

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
# define path
path = r'C:\Users\heidi\Desktop\Instacart Basket Analysis 01-09-2022'

# %%
# import orders_products_combined
df_ords_prods_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
# define Function
def add_num(x , y):
    sum = x + y
    return sum

# %%
# Run Function
add_num(9, 11)
# Out:
# 20

# %% [markdown]
# # 2 If Statements

# %%
df = df_ords_prods_merged[:1000000]

# %%
# define function label price 
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High-range product'
  else: return 'Not enough data'

# %%
# use price_label fn
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\heidi\AppData\Local\Temp/ipykernel_23792/1780448413.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
# shape of new df
df.shape
# Out:
# (1000000, 16)

# %%
df.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     0.0         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered product_name  aisle_id  department_id  prices _merge  \
# ...

# %%
# find value counts
df['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
# find highest priced item
df['prices'].max()
# Out:
# 14.8

# %% [markdown]
# # 3 If Statements with the loc() Function

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range_loc, dtype: int64

# %%
# apply loc() function on full dataframe
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_ords_prods_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# NaN                   21104410
# Low-range product     10126321
# Mid-range product       756450
# High-range product      417678
# Name: price_range_loc, dtype: int64

# %% [markdown]
# # 4 If Statements with For-Loops

# %%
# find frequency in days of week orders
df_ords_prods_merged['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %%
# create for-loop
result = []

for value in df_ords_prods_merged["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy day")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy day',
#  'Least busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy day',
#  'Least busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
# create new column to house result for-loop
df_ords_prods_merged['busiest_day'] = result

# %%
# see value counts of results
df_ords_prods_merged['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy day     3783802
# Name: busiest_day, dtype: int64

# %% [markdown]
# # 5 Task

# %% [markdown]
# ## 02. Suppose your clients have changed their minds about the labels you created in your “busiest_day” column. Now, they want “Busiest day” to become “Busiest days” (plural). This label should correspond with the two busiest days of the week as opposed to the single busiest day. At the same time, they’d also like to know the two slowest days. Create a new column for this using a suitable method.

# %%
# create column using loc()
df_ords_prods_merged.loc[(df_ords_prods_merged['orders_day_of_week'] == 1) | (df_ords_prods_merged['orders_day_of_week'] == 0), 'busiest_days'] = 'Busiest days'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['orders_day_of_week'] == 4) | (df_ords_prods_merged['orders_day_of_week'] == 3), 'busiest_days'] = 'Least busy days'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['orders_day_of_week'] == 6) | (df_ords_prods_merged['orders_day_of_week'] == 2) | (df_ords_prods_merged['orders_day_of_week'] == 5), 'busiest_days'] = 'Regularly busy days'

# %% [markdown]
# ## 03. Check the values of this new column for accuracy. Note any observations in markdown format.

# %%
# see value counts of results
df_ords_prods_merged['busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy days    12916111
# Busiest days           11864412
# Least busy days         7624336
# Name: busiest_days, dtype: int64

# %% [markdown]
# The 3 regularly busy days together make up more revenue than the 2 busiest days by about a million dollars

# %% [markdown]
# ## 04. When too many users make Instacart orders at the same time, the app freezes. The senior technical officer at Instacart wants you to identify the busiest hours of the day. Rather than by hour, they want periods of time labeled “Most orders,” “Average orders,” and “Fewest orders.” Create a new column containing these labels called “busiest_period_of_day.”

# %%
#check freq for order_hour_of_day
df_ords_prods_merged['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: order_hour_of_day, dtype: int64

# %%
# create ranges based on number of orders
df_ords_prods_merged.loc[(df_ords_prods_merged['order_hour_of_day'] >= 8) & (df_ords_prods_merged['order_hour_of_day'] <= 17), 'busiest_period_of_day'] = 'Most orders'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['order_hour_of_day'] >= 0) & (df_ords_prods_merged['order_hour_of_day'] <= 7), 'busiest_period_of_day'] = 'Fewest orders'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['order_hour_of_day'] >= 18) & (df_ords_prods_merged['order_hour_of_day'] <= 23), 'busiest_period_of_day'] = 'Average orders'

# %% [markdown]
# ## 05. Print the frequency for this new column.

# %%
# see value counts of results
df_ords_prods_merged['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most orders       24923843
# Average orders     5703141
# Fewest orders      1777875
# Name: busiest_period_of_day, dtype: int64

# %% [markdown]
# ## 07. Export your dataframe as a pickle file (since you added new columns) and store it correctly in your “Prepared Data” folder.

# %%
df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.4.7.pkl'))
